# %% [markdown]
# <div style="border:solid blue 2px; padding: 20px">
#
# **Hello Michael,**
#
#
#
# Thank you for thoroughly addressing all the points raised in the previous reviews.
#
# I truly appreciate the care you’ve taken in fixing each issue. The project looks excellent now.
#
# Congratulations once again on your journey and accomplishments. Your project has been accepted — fantastic work! This is just the beginning of many exciting milestones ahead, and I’m confident you’ll continue to grow and excel with each step you take.
#
# Keep up the amazing work! 🪄

# %% [markdown]
# <div style="border:solid blue 2px; padding: 20px">
#
# **Hello Michael,**
#
# Thank you so much for addressing the issues from the previous review. You’ve done a great job fixing most of the red comments perfectly — well done!
#
# Just a few items remain to be addressed. Please take your time to fix them and resubmit when you’re ready.
#
# You’re making excellent progress, and with a little more effort, I’m confident you’ll finalize everything beautifully. Keep pushing forward — you’ve got this! 🌟
#
# Looking forward to your updated submission!
#
# </div>

# %% [markdown]
# <div style="border:solid blue 2px; padding: 20px">
#
# **Hello Michael,**
#
# Congratulations on submitting your second Python practical project! 🎉
#
# You’re making fantastic progress, and every project you complete brings you closer to mastering the skills needed to excel in data analysis. Your dedication and hard work are evident, and you should be proud of this achievement.
#
# Keep up the great momentum — let’s dive into this project together!
#
# ---
#
# You’ll find specific notes inside the project file, marked in green, yellow, or red. Below is a quick guide to what each color represents. **Note:** Please do not remove or alter my comments, as they’ll help guide future reviews and make the process smoother for both of us.
#
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer’s Comment</b>
#
# These comments highlight efficient solutions and great ideas that you can apply to future projects.
# </div>
#
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Reviewer’s Comment</b>
#
# These comments point out areas for optimization. While corrections are not mandatory, addressing them will enhance your project.
# </div>
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer’s Comment</b>
#
# These comments indicate issues that must be resolved before your project can be accepted.
# </div>
#
#
# ---
#
# Feel free to add your own comments, explain the changes you’ve made, or ask questions by using the example below. Simply copy and paste the code into a Markdown cell:
#
# ```
# <div class="alert alert-info"; style="border-left: 7px solid blue">
# <b>Student’s Comment</b></div>
# ```
#
# It will appear like this:
#
# <div class="alert alert-info"; style="border-left: 7px solid blue">
# <b>Student’s Comment</b></div>
#
# ---
#
# Revisions are a natural and essential part of the learning process, so don’t be discouraged! Take your time to review the feedback and make the necessary updates. Once you’re ready, resubmit the project, and I’m confident you’ll excel on your next attempt.
#
# Remember, every challenge is an opportunity to grow. You’ve got this! 🏄
#
# </div>

# %% [markdown]
# Project Title
# Exploratory Data Analysis Using Instacart Orders
#
# Overview
# Utilizing datasets provided by Instacart, this project will do the following:
# Read the datasets
# Cleanup and verify the data provided
# Provide insights into the shopping habbits of Instacart users.
#
# Description of Datasets
# Five datasets are used, all utilize a ; as a seperator.
# instacart_orders - This dataset contains the order details
# products - This dataset contains information on each product that can be ordered
# aisles - This dataset contains information on the aisles where products can be found
# departments - This dataset contains information on the department the products can be found
# order_products - This dataset contains information on each product added to a unique order
#
# Strategy
# After importing the datasets, the accuracy of the data will be examined and any issues resolved.
# After this step paterns in the data will be looked at, including:
# What day and hour is most is most popular? What products are the most popular? What products are reordered most?

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 3</b>
#
# ✔️
#
#
#
# <div class="alert alert-warning" style="border-left: 7px solid gold">
# <b>⚠️ Reviewer's Comment, v. 2</b>
#
# Well done on the instroduction. However, please use Markdown cells for comments and conclusions, as this format is intended for descriptive text. Code cells should contain only brief comments specifically related to the code.
#
# To change a cell type to Markdown, use the top navigation bar: create a new cell with the `+` button, then select the cell and choose "Markdown" from the dropdown menu where it currently says "Code."
#
#
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 1</b>
#
#
# A project title and introduction are essential to provide context and clarity to your work. Please ensure these elements are included.
#
# For the introduction, it would be most effective to cover the following:
#
# - A brief overview of the situation or problem being addressed;
# - A clear statement of the project's objective, outlining what you aim to achieve;
# - A description of the dataset(s) you'll be using, highlighting key attributes and any relevant details;
# - A brief plan or strategy detailing how you intend to reach your goal.
#
# </div>

# %%
# Import Libraries
import pandas as pd
from matplotlib import pyplot as plt

# %%
# Step 1: Open the datafiles
# Read CSVs with Pandas:
# df = pd.read_csv('')
instacart_orders = pd.read_csv('/datasets/instacart_orders.csv', sep=';')
products = pd.read_csv('/datasets/products.csv', sep=';')
aisles = pd.read_csv('/datasets/aisles.csv', sep=';')
departments = pd.read_csv('/datasets/departments.csv', sep=';')
order_products = pd.read_csv('/datasets/order_products.csv', sep=';')

# %%
# Step 1: look at the general contects
# look at headers
print(instacart_orders.head(0)) #no issues found with headers
print(products.head(0))
print(aisles.head(0))
print(departments.head(0))
print(order_products.head(0))

#Step 1: look at the general contects
# Checking data types
print()
print('instatcart_orders DF')
print(instacart_orders.info())
print()
print('products DF')
print(products.info())
print()
print('aisles DF')
print(aisles.info())
print()
print('departments DF')
print(departments.info())
print()
print('order_products DF')
print(order_products.info())
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []
# Empty DataFrame
# Columns: [aisle_id, aisle]
# Index: []
# Empty DataFrame
# Columns: [department_id, department]
# Index: []
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []
#
# instatcart_orders DF
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
# ...

# %% [markdown]
# After examining the general information of the dataframes he following key takeaways were noted:
#
# intstacart_oders
# Most columns contained 478967 datapoints however the days_since_prior_order only contained 450148. days_since_prior_order is also a type float.
#
# products DF
# the product_name column contained 48436 data points while all others contained 49694.
#
# order_products
# The add_to_cart order is of type float.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 3</b>
#
# ✔️ Well done.
#
#
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 2</b>
#
# Please still write down what you noticed after looking at the dataframes - do they have missing values? Do the column types are optimal everywhere?
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 1</b>
#
# In this section, please also get familiar with the datasets. First, use `head()` method to display first lines. And then use `info()` method. It will allow you to see the size of the dataframe, which types of data are used (whether the types are optimal), whether there are missing data in the dataframes.
#
# After you've studied the data don't forget to write a brief summary of your observations.
#
#
#
# In your observations, it is recommended to include the following:
#
# - **Column names** – Indicate if any columns require renaming.
# - **Data types** – Verify whether the current data types are optimal or need modification.
# - **Missing values** – If the non-null count is less than the total number of entries, this indicates missing values.
#
# You can easily obtain this information from the `head()` and `info()` methods on your dataset.

# %% [markdown]
# ## Find and remove duplicate values (and describe why you make your choices)

# %% [markdown]
# ### `orders` data frame

# %%
# Check for duplicated orders
# checking for standard dupliactes:

print("Number of duplicate rows: ")
print(instacart_orders.duplicated().sum()) #15 duplicate rows were found

#duplicate_orders=instacart_orders[instacart_orders.duplicated()] #just looking
#print(duplicate_orders) #just looking
# Out:
# Number of duplicate rows:
# 15

# %%
# Check for all orders placed Wednesday at 2:00 AM

#print(instacart_orders.head(2)) #this just gets the header names

wednesday_orders = instacart_orders[(instacart_orders['order_dow']==3) & (instacart_orders['order_hour_of_day']==2)]

print(wednesday_orders)
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838     2766110   162084            41          3                  2
# 5156     2190225   138285            18          3                  2
# 15506     553049    58599            13          3                  2
# 18420     382357   120200            19          3                  2
# 24691     690242    77357             2          3                  2
# ...          ...      ...           ...        ...                ...
# 457013   3384021    14881             6          3                  2
# 458816    910166   164782            18          3                  2
# 459635   1680532   106435             6          3                  2
# 468324    222962    54979            59          3                  2
# 477526   2592344    46860            38          3                  2
#
#         days_since_prior_order
# 4838                      16.0
# 5156                      11.0
# ...

# %%
# Remove duplicate orders
# Use drop duplicates to drop the duplicate rows found above
instacart_orders = instacart_orders.drop_duplicates().reset_index()

# %%
# Double check for duplicate rows
print("Number of duplicate rows: ")
print(instacart_orders.duplicated().sum()) #0 found, previously this was 15
# Out:
# Number of duplicate rows:
# 0

# %%
# Double check for duplicate order IDs only

#print(instacart_orders.info()) #order_id has 478952 
#print(instacart_orders['order_id'].nunique()) #order_id has 478952 unique therefore no duplicates

# Use duplicated and count duplicates of order_id
print ("Number of duplicate order IDs: ")
print(instacart_orders['order_id'].duplicated().sum())
# Out:
# Number of duplicate order IDs:
# 0

# %% [markdown]
# <div class="alert alert-success" style="border-left: 7px solid green">
# <b>✅ Reviewer's Comment, v. 1</b>
#
# Well done! You have completed all the necessary checks and data pre-processing.
# </div>

# %% [markdown]
# #In this section the accuracy of the data was examined. 15 duplicate rows were found. The duplicate rows were fully duplicate and were removed.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 2</b>
#
# ✔️
#
#
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 1</b>
#
#
# It is highly recommended to add a conclusion or summary ***at the end of each section***. This should briefly describe your observations and highlight any major outcomes from your analysis for a business customer, framing them in a way that directly addresses the concerns and interests of business stakeholders.

# %% [markdown]
# ### `products` data frame

# %%
# Check for fully duplicate rows
print("Number of duplicate product rows: ")
print(products.duplicated().sum())
# Out:
# Number of duplicate product rows:
# 0

# %%
# Check for just duplicate product IDs
#print(products.info())
#print(products['product_id'].nunique())
#product_id contains 49694 and 49694 unique
print("Number of duplicate product IDs:")
print(products['product_id'].duplicated().sum())
# Out:
# Number of duplicate product IDs:
# 0

# %%
# Check for just duplicate product names (convert names to lowercase to compare better)

#make a new column with lower case product names
products['product_name_lower']=products['product_name'].str.lower()

#Next line will remove all duplicates based on the lowercase product name"
#products=products.drop_duplicates(subset=['product_name_lower'], keep='first').reset_index()

#count duplicates
duplicate_names = products['product_name_lower'].duplicated()

print("Number of duplicated product names:")
print(duplicate_names.sum())

#print(products[products['product_name_lower'].duplicated()]) #just looking
# Out:
# Number of duplicated product names:
# 1361

# %%
# Check for duplicate product names that aren't missing

#Next line will drop NA values:
#products=products.dropna()

print("Number of missing product names: ")
print(duplicate_names.sum() - products['product_name_lower'].isna().sum()-1) #-1 because NA is a duplicate

#This is the number of missing product names
#print(products['product_name_lower'].isna().sum())

#print(products.info()) #just to see if I dropped too many
# Out:
# Number of missing product names:
# 102

# %% [markdown]
# #In this section the accuracy of the products dataframe was examined. No duplicate rows were found however the 'product_name' did contain mixed cases. After creating a new column and converting all product names to lower case 1361 duplicates were found. Additionally, 102 product names were missing.

# %% [markdown]
# <div class="alert alert-success" style="border-left: 7px solid green">
# <b>✅ Reviewer's Comment, v. 1</b>
#
# Well done!
# </div>

# %% [markdown]
# ### `departments` data frame

# %%
#overview of data
#print(departments.info())
#print(departments)

# Check for fully duplicate rows
print("Number of duplicate department rows: ")
print(departments.duplicated().sum())
# Out:
# Number of duplicate department rows:
# 0

# %%
#count duplicates
duplicate_departments = departments['department'].duplicated()

print("Number of duplicated depratment names:")
print(duplicate_departments.sum())
# Out:
# Number of duplicated depratment names:
# 0

# %% [markdown]
# #The accuracy of the departments dataframe was examined. No duplicates or missing values were discovered.

# %% [markdown]
# ### `aisles` data frame

# %%
#overview of data
#print(aisles.info())
#print(aisles.sample(10))

# Check for fully duplicate rows
print("Number of duplicate aisle rows: ")
print(aisles.duplicated().sum())
# Out:
# Number of duplicate aisle rows:
# 0

# %%
#make a new column with lower case product names
aisles['aisle_lower']=aisles['aisle'].str.lower()

print("Duplicated aisle names: ")
print(aisles['aisle_lower'].duplicated().sum())
# Out:
# Duplicated aisle names:
# 0

# %% [markdown]
# #The accuracy of the aisles dataframe was examined. A new column was created and populated with fully lowercase aisle names. No other issues were found.

# %% [markdown]
# <div class="alert alert-success" style="border-left: 7px solid green">
# <b>✅ Reviewer's Comment, v. 1</b>
#
# All good.</div>

# %% [markdown]
# ### `order_products` data frame

# %%
#overview of data
#print(order_products.info())
#print(order_products.sample(10))

# Check for fullly duplicate rows

print("Number of duplicate order prodcut rows: ")
print(order_products.duplicated().sum())
# Out:
# Number of duplicate order prodcut rows:
# 0

# %%
# Double check for any other tricky duplicates

#looking for missing values
print("number NaN add to Cart Order:")
print(order_products['add_to_cart_order'].isna().sum())

tricky_duplicates = order_products[order_products.duplicated(subset=['order_id', 'product_id'])]
print(tricky_duplicates)

tricky_duplicates1 = order_products[order_products.duplicated(subset=['order_id', 'add_to_cart_order'])]
print(tricky_duplicates1)

tricky_duplicates2 = order_products[order_products.duplicated(subset=['order_id','add_to_cart_order','product_id'])]
print(tricky_duplicates2)
# Out:
# number NaN add to Cart Order:
# 836
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []
#          order_id  product_id  add_to_cart_order  reordered
# 64336     1717990       39408                NaN          0
# 70057      264710       41602                NaN          0
# 128360    2449164       14386                NaN          0
# 137029    3347453       30727                NaN          0
# 137958    2136777       45106                NaN          0
# ...           ...         ...                ...        ...
# 4505662   1800005        7411                NaN          0
# 4511400   1633337         260                NaN          0
# 4517562    404157        9517                NaN          0
# 4534112   1673227       17835                NaN          0
# 4535739   1832957       17949                NaN          1
#
# [766 rows x 4 columns]
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %% [markdown]
# <div class="alert alert-success" style="border-left: 7px solid green">
#
# <b>✅ Reviewer's comment, v. 1</b>
#
#
# Well done. When checking for duplicates, it's important to look beyond full duplicates and also verify the uniqueness of combinations that should be unique.

# %% [markdown]
# #The order_products dataframe was examined. No duplicate rows and 836 missing values were found.

# %% [markdown]
# ## Find and remove missing values

# %% [markdown]
# ### `products` data frame

# %%
#Next line will drop NA values:
#products=products.dropna()

print("Number of missing product names: ")
#print(duplicate_names.sum() - products['product_name_lower'].isna().sum())
print(products['product_name_lower'].isna().sum())

missing_products=products[products['product_name_lower'].isna()]

print(missing_products)
# Out:
# Number of missing product names:
# 1258
#        product_id product_name  aisle_id  department_id product_name_lower
# 37             38          NaN       100             21                NaN
# 71             72          NaN       100             21                NaN
# 109           110          NaN       100             21                NaN
# 296           297          NaN       100             21                NaN
# 416           417          NaN       100             21                NaN
# ...           ...          ...       ...            ...                ...
# 49552       49553          NaN       100             21                NaN
# 49574       49575          NaN       100             21                NaN
# 49640       49641          NaN       100             21                NaN
# 49663       49664          NaN       100             21                NaN
# 49668       49669          NaN       100             21                NaN
#
# [1258 rows x 5 columns]

# %%
# Are all of the missing product names associated with aisle ID 100?
print(missing_products['aisle_id'].unique()) #prints unique aisle ID, only '100' is found
# Out:
# [100]

# %%
# Are all of the missing product names associated with department ID 21?
print(missing_products['department_id'].unique()) #prints unique department ID, only '21' is found
# Out:
# [21]

# %%
# What is this ailse and department?
print(aisles['aisle'].loc[aisles['aisle_id']==100])

print(departments['department'].loc[departments['department_id']==21])
# Out:
# 99    missing
# Name: aisle, dtype: object
# 20    missing
# Name: department, dtype: object

# %%
# Fill missing product names with 'Unknown'
products['product_name_lower']=products['product_name_lower'].fillna('Unknown')

print(products['product_name_lower'].isna().sum()) #checking the number of NA
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success" style="border-left: 7px solid green">
#
# <b>✅ Reviewer's comment, v. 1</b>
#
#
# Great job.

# %% [markdown]
# 1258 missing datapoints were found int he products dataframe. All were associated with aisle 100 and department 21, both appropriately labeled "missing". The missing datapoints were then filled with "Unknown".

# %% [markdown]
# ### `orders` data frame

# %%
print(instacart_orders.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478952 entries, 0 to 478951
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   index                   478952 non-null  int64
#  1   order_id                478952 non-null  int64
#  2   user_id                 478952 non-null  int64
#  3   order_number            478952 non-null  int64
#  4   order_dow               478952 non-null  int64
#  5   order_hour_of_day       478952 non-null  int64
#  6   days_since_prior_order  450135 non-null  float64
# dtypes: float64(1), int64(6)
# memory usage: 25.6 MB
# None

# %%
# Are there any missing values where it's not a customer's first order?
#print(instacart_orders.isna().sum()) #checking the number of NA 

#getting missing orders
missing_orders=instacart_orders[instacart_orders['days_since_prior_order'].isna()]

print('Missing orders numbers:')
print(missing_orders['order_number'].unique()) #1 therefore always the first order
# Out:
# Missing orders numbers:
# [1]

# %% [markdown]
# The orders data frame was examined. It was verified that any instance of a missing days since previous order was when it was the customer's first order.

# %% [markdown]
# ### `order_products` data frame

# %%
print(order_products.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  float64
#  3   reordered          int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB
# None

# %%
# What are the min and max values in this column?
# Which column?

print("Min and Max of order_id:")
print(order_products['order_id'].min(), order_products['order_id'].max())
print()
print("Min and Max of product_id:")
print(order_products['product_id'].min(), order_products['product_id'].max())
print()
print("Min and Max of add_to_cart_order:")
print(order_products['add_to_cart_order'].min(), order_products['add_to_cart_order'].max())
print()
print("Min and Max of reordered:")
print(order_products['reordered'].min(), order_products['reordered'].max())
# Out:
# Min and Max of order_id:
# 4 3421079
#
# Min and Max of product_id:
# 1 49694
#
# Min and Max of add_to_cart_order:
# 1.0 64.0
#
# Min and Max of reordered:
# 0 1

# %%
# Save all order IDs with at least one missing value in 'add_to_cart_order'

# getting missing orders
missing_order_ids=order_products[order_products['add_to_cart_order'].isna()]['order_id'].unique()
print(missing_order_ids)

#print(order_products['order_id']['add_to_cart_order'].isna())
# Out:
# [2449164 1968313 2926893 1717990 1959075  844733   61355  936852  264710
#  1564093  129627  293169 2849370 1386261 3308010  903110 2136777 3347453
#  1888628  165801 2094761 1038146 2997021  813364 2256933  171934 2409109
#  1730767 1169835  733526  404157 3125735  747668 1800005 1961723  871281
#   388234 1648217 1477139  102236 1021563 1832957 2721963  678116 1220886
#  1673227 2999801 1633337 2470674 2625444 1677118 2479011 3383594 1183255
#  1713430 2652650 1598369 1916118  854647 1302315  888470  180546 2621907
#  1308785 2729254    9310 2170451 2979697 1625713 1529171]

# %%
# Do all orders with missing values have more than 64 products?
counts_per_order = order_products[order_products['order_id'].isin(missing_order_ids)].groupby('order_id').size()
print('The minimum products ordered is:')
print(counts_per_order.min())
#min is 65, therefor all have more than 64
# Out:
# The minimum products ordered is:
# 65

# %%
# Replace missing values with 999 and convert column to integer type
order_products['add_to_cart_order'].fillna(999,inplace=True)

order_products['add_to_cart_order'] = order_products['add_to_cart_order'].astype(int)

#print(order_products.info()) #verifying conversion

# %% [markdown]
# Ranges for all columns were shown to be expected. However add_to_cart_order as a float. 70 orders were identified with at least one value missing in 'add_to_cart_order'. This occurred on exclusively on orders with more than 64 products. This may indicate that an issue is present with orders containing more than 64 items. All missing values were replaced with '999' and the datatype changed to integer.

# %% [markdown]
# <div class="alert alert-success" style="border-left: 7px solid green">
#
# <b>✅ Reviewer's comment, v. 1</b>
#
#
# You've done a great job pre-processing the data and preparing it for further analysis.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 3</b>
#
# ✔️
#
#
#
# <div class="alert alert-warning" style="border-left: 7px solid gold">
# <b>⚠️ Reviewer's Comment, v. 2</b>
#
# When conducting your analysis, try to focus on takeaways that are relevant to the business. For example, in this case, you could highlight the following insight:
#
# ---
#
# In our dataset, the highest add-to-cart order number is 64. Orders with missing values in this field correspond to items added beyond the 64th position (between 65 and 127 items). This indicates a potential technical issue with assigning add-to-cart order numbers for items added after the 64th.
#
# ---
#
# In a real-world scenario, it would be important to escalate this issue to the relevant team for resolution.
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 1</b>
#
# Just do not forget to write your observations.

# %% [markdown]
# # [A] Easy (must complete all to pass)

# %% [markdown]
# ### [A1] Verify that the `'order_hour_of_day'` and `'order_dow'` values in the `orders` tables are sensible (i.e. `'order_hour_of_day'` ranges from 0 to 23 and `'order_dow'` ranges from 0 to 6)

# %%
#print(instacart_orders.info()) #get info
#order_hour_of_day is type int
#order_dow is type int

print("Min and Max of hour of day:")
print(instacart_orders['order_hour_of_day'].min(), instacart_orders['order_hour_of_day'].max())
#print(instacart_orders['order_hour_of_day'].unique()) #all values are unique and sensible
print()
print("Min and Max order day:")
print(instacart_orders['order_dow'].min(), instacart_orders['order_dow'].max())
#print(instacart_orders['order_dow'].unique()) #all values are unique and sensible

# types are in, data is in expected range, and is sensible
# Out:
# Min and Max of hour of day:
# 0 23
#
# Min and Max order day:
# 0 6

# %% [markdown]
# ### [A2] What time of day do people shop for groceries?

# %%
orders_per_hour=instacart_orders.groupby('order_hour_of_day')['order_hour_of_day'].count()

print('When do people shop for groceries:')
print(orders_per_hour)

orders_per_hour.plot(kind='line',y='orders_per_hour', title='Orders per Hour', ylabel='orders', xlabel='hour')
plt.show()
# Out:
# When do people shop for groceries:
# order_hour_of_day
# 0      3180
# 1      1763
# 2       989
# 3       770
# 4       765
# 5      1371
# 6      4215
# 7     13043
# 8     25024
# 9     35896
# 10    40578
# 11    40032
# 12    38034
# 13    39007
# 14    39631
# 15    39789
# 16    38112
# 17    31930
# 18    25510
# 19    19547
# 20    14624
# 21    11019
# 22     8512
# 23     5611
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# #What time of day do people shop for groceries?
# #Count each instance of order_hour
# #Plotting the results shows that 1000 is the most popular time to order groceries.
# #With the heaviest between 1000 and 1500. A small downtick is present during lunch.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green"> <b>✅ Reviewer’s Comment, v. 1</b>
#
# Great job! You've created an excellent chart with all the required elements, including a clear title, labeled axes, and appropriate scales. You've also drawn accurate conclusions from it.

# %% [markdown]
# ### [A3] What day of the week do people shop for groceries?

# %%
orders_per_day=instacart_orders.groupby('order_dow')['order_dow'].count()

#print(orders_per_day)

orders_per_day.plot(kind='line',y='orders_per_day', xlabel='day',ylabel='orders',title='Orders per Day')
plt.show()

# %% [markdown]
# What day of the week do people shop for groceries?
# Discord showed that 0=Sunday, though this was not included elsewhere.
# Count the number of times an order is placed for each order_dow.
# Plotting the results show that Sunday is by far the most popular day to order groceries with a sharp decline after Monday.

# %% [markdown]
# ### [A4] How long do people wait until placing another order?

# %%
#Group by number of days and count each 
days_since_order=instacart_orders.groupby('days_since_prior_order')['days_since_prior_order'].count()

#print(days_since_order)

days_since_order.plot(kind='line',y='days_since_order', xlabel='days',ylabel='orders',title='Days Since Last Order')
plt.show()

# %% [markdown]
# How long do people wait until placing another order?
# The strategy for finding the solution is to:
# Count times each days_since_last_order appears for a unique order.
# Plotting the results shows two peaks:
# The first peak appears one week after placing an order.
# The second, and higher, peak appears one month after placing an order.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green"> <b>✅ Reviewer’s Comment, v. 1</b>
#
# You answered all the questions correctly.

# %% [markdown]
# # [B] Medium (must complete all to pass)

# %% [markdown]
# ### [B1] Is there a difference in `'order_hour_of_day'` distributions on Wednesdays and Saturdays? Plot the histograms for both days and describe the differences that you see.

# %%
#wednesday_orders dow = 3
wednesday_orders = instacart_orders[instacart_orders['order_dow']==3] 

wednesday_orders['order_hour_of_day'].plot(kind='hist', alpha=0.3, bins=24, title='Orders by Hour')

#saturday_orders dow=6
saturday_orders = instacart_orders[instacart_orders['order_dow']==6] 

saturday_orders['order_hour_of_day'].plot(kind='hist',bins=24, alpha=0.3)
plt.xlabel('Hour')
plt.ylabel('Orders')
plt.legend(['Wed','Sat'])
plt.show()

# %% [markdown]
# The graph demonstrates that the number of orders per hour for Saturday and Wednesday are very similar.
# The largest exception being the Saturday lunch rush is busier and longer in duration.
# Wednesday has two peaks at either end of the lunch rush and higher sales leading up to and just after this period.
# Additionally, Saturday sales are higher three hours before and after midnight.

# %% [markdown]
# ### [B2] What's the distribution for the number of orders per customer?

# %%
#print(instacart_orders.head(0)) #this is just to look at the headers

#unique_customers=instacart_orders['user_id'].unique()

#sort by user_id and count the number of orders
orders_per_customer = instacart_orders.groupby('user_id')['order_id'].count()
print(orders_per_customer.describe())

orders_per_customer.plot(kind='hist',y='orders_per_customer', title='Orders per Customer')
plt.xlabel('Customers')
plt.ylabel('Orders')
plt.show()
# Out:
# count    157437.000000
# mean          3.042182
# std           2.746842
# min           1.000000
# 25%           1.000000
# 50%           2.000000
# 75%           4.000000
# max          28.000000
# Name: order_id, dtype: float64

# %% [markdown]
# What is the distribution of orders per customer?
# The strategy to find the solution is:
# Sort by User ID and count the number of unique orders.
# The mean is 3

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green"> <b>✅ Reviewer’s Comment, v. 1</b>
#
# Excellent.

# %% [markdown]
# ### [B3] What are the top 20 popular products (display their id and name)?

# %%
#Merge DFs to get name and ID
product_merge=order_products.merge(products,on='product_id')

#count each instance
product_counts=product_merge.groupby(['product_id', 'product_name']).size().reset_index(name='count')

# Sort and get the top 20 products
top_20_products = product_counts.sort_values(by='count', ascending=False).head(20)

print(top_20_products)
# Out:
#        product_id              product_name  count
# 22332       24852                    Banana  66050
# 11772       13176    Bag of Organic Bananas  53297
# 18970       21137      Organic Strawberries  37039
# 19660       21903      Organic Baby Spinach  33971
# 42362       47209      Organic Hass Avocado  29773
# 42863       47766           Organic Avocado  24689
# 42739       47626               Large Lemon  21495
# 15037       16797              Strawberries  20018
# 23546       26209                     Limes  19690
# 25022       27845        Organic Whole Milk  19600
# 25129       27966       Organic Raspberries  19197
# 20590       22935      Organic Yellow Onion  15898
# 22431       24964            Organic Garlic  15292
# 40374       45007          Organic Zucchini  14584
# 35248       39275       Organic Blueberries  13879
# 44601       49683            Cucumber Kirby  13675
# 25345       28204        Organic Fuji Apple  12544
# ...

# %% [markdown]
# What are the top 20 popular products?
# The strategy to find the solution is:
# I merged the products and product orders DFs to get all required information.
# Next count of each time it was ordered.
# I sorted the results to find the top 20.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 2</b>
#
# ✔️ Excellent execution.
#
#
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 1</b>
#
# You don't need to create a new dataframe. Please try to merge `order_products` and `products` dataframes. Then group the merged dataframe by product name and product ID and count the number of orders for each product. Then sort the result and get the top 20. The current list is incorrect.

# %% [markdown]
# # [C] Hard (must complete at least two to pass)

# %% [markdown]
# ### [C1] How many items do people typically buy in one order? What does the distribution look like?

# %%
#How many unique product IDs are there on an order ID?

items_per_order = order_products.groupby('order_id')['product_id'].count()

print(items_per_order.describe())

items_per_order.plot(kind='hist',y='items_per_order',title='Items per Order')
plt.xlabel('Number of Items')
plt.ylabel('Number of Orders')
plt.show()
# Out:
# count    450046.000000
# mean         10.098983
# std           7.540206
# min           1.000000
# 25%           5.000000
# 50%           8.000000
# 75%          14.000000
# max         127.000000
# Name: product_id, dtype: float64

# %% [markdown]
# How many items do people typically buy in one order?
# The strategy to find the solution is:
# Count the number of unique product IDs in each order.
# The mean is 10

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 1</b>
#
# ✔️

# %% [markdown]
# ### [C2] What are the top 20 items that are reordered most frequently (display their names and product IDs)?

# %%
#Merge DFs to get name and ID
reorder_merge=order_products.merge(products,on='product_id')

#count each instance
reorder_counts=reorder_merge.groupby(['product_id', 'product_name'])['reordered'].sum().reset_index(name='count')

# Sort and get the top 20 products
top_20_products = reorder_counts.sort_values(by='count', ascending=False).head(20)

print(top_20_products)
# Out:
#        product_id              product_name  count
# 22332       24852                    Banana  55763
# 11772       13176    Bag of Organic Bananas  44450
# 18970       21137      Organic Strawberries  28639
# 19660       21903      Organic Baby Spinach  26233
# 42362       47209      Organic Hass Avocado  23629
# 42863       47766           Organic Avocado  18743
# 25022       27845        Organic Whole Milk  16251
# 42739       47626               Large Lemon  15044
# 25129       27966       Organic Raspberries  14748
# 15037       16797              Strawberries  13945
# 23546       26209                     Limes  13327
# 20590       22935      Organic Yellow Onion  11145
# 22431       24964            Organic Garlic  10411
# 40374       45007          Organic Zucchini  10076
# 44601       49683            Cucumber Kirby   9538
# 25345       28204        Organic Fuji Apple   8989
# 7400         8277  Apple Honeycrisp Organic   8836
# ...

# %% [markdown]
# What are the top 20 items that are reordered:
# The strategy to find the solution is:
# First merge the products and product_id DFs to get all necessary information.
# Next, count all instances of reorder by product. and  sorted the result to find the top 20.
# Display the results.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 3</b>
#
# ✔️
#
#
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 2</b>
#
# You made an excellent start. However, in the third line you need to use `reorder_counts`, not `product_counts`. Could you please update the code? The list will also be changed.
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 1</b>
#
# Please use the approach I described above. Currently, the list is incorrect. The most popular product in all the lists will be Bananas.

# %% [markdown]
# ### [C3] For each product, what proportion of its orders are reorders?

# %%
#Merge sales and products
reorder_pct = order_products.merge(products)

#Get the reorder ratio
reorder_pct = reorder_pct.groupby(['product_id', 'product_name'])['reordered'].mean().to_frame()

#Format the output
reorder_pct.head(20).style.format({'reordered': '{:.1%}'}) #format to percentage with 1 decimal
# Out:
# <style  type="text/css" >
# </style><table id="T_8ca9d_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >reordered</th>    </tr>    <tr>        <th class="index_name level0" >product_id</th>        <th class="index_name level1" >product_name</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8ca9d_level0_row0" class="row_heading level0 row0" >1</th>
#                         <th id="T_8ca9d_level1_row0" class="row_heading level1 row0" >Chocolate Sandwich Cookies</th>
#                         <td id="T_8ca9d_row0_col0" class="data row0 col0" >56.4%</td>
#             </tr>
#             <tr>
#                         <th id="T_8ca9d_level0_row1" class="row_heading level0 row1" >2</th>
#                         <th id="T_8ca9d_level1_row1" class="row_heading level1 row1" >All-Seasons Salt</th>
# ...

# %% [markdown]
# What is the proportion of orders to reorders for each product?
# The strategy to find the solution is:
# Count each instance of the first order for each product.
# Count each instance of the reorder for each product.
# Divide the two to find the reorder percent.
# Merge to add the product name.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 2</b>
#
# ✔️ Well done.
#
#
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 1</b>
#
# Please see below, how you can solve the task.

# %%
#ADDED BY REVIEWER

#Upload the dataframes. You can skip that step and use your own dataframes
df_order_products = pd.read_csv('/datasets/order_products.csv', sep=';')
df_products = pd.read_csv('/datasets/products.csv', sep=';')

#Merge sales and products
reorder_pct = df_order_products.merge(df_products)

#Get the reorder ratio
reorder_pct = reorder_pct.groupby(['product_id', 'product_name'])['reordered'].mean().to_frame()

#Format the output
reorder_pct.head(20).style.format({'reordered': '{:.1%}'}) #format to percentage with 1 decimal
# Out:
# <style  type="text/css" >
# </style><table id="T_b95dc_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >reordered</th>    </tr>    <tr>        <th class="index_name level0" >product_id</th>        <th class="index_name level1" >product_name</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b95dc_level0_row0" class="row_heading level0 row0" >1</th>
#                         <th id="T_b95dc_level1_row0" class="row_heading level1 row0" >Chocolate Sandwich Cookies</th>
#                         <td id="T_b95dc_row0_col0" class="data row0 col0" >56.4%</td>
#             </tr>
#             <tr>
#                         <th id="T_b95dc_level0_row1" class="row_heading level0 row1" >2</th>
#                         <th id="T_b95dc_level1_row1" class="row_heading level1 row1" >All-Seasons Salt</th>
# ...

# %% [markdown]
# ### [C4] For each customer, what proportion of their products ordered are reorders?

# %%
#Merge sales and products
customer_reorder_pct = order_products.merge(instacart_orders)

#Get the reorder ratio
customer_reorder_pct = customer_reorder_pct.groupby(['user_id'])['reordered'].mean().to_frame()

#Format the output
customer_reorder_pct.head(20).style.format({'reordered': '{:.1%}'}) #format to percentage with 1 decimal
# Out:
# <style  type="text/css" >
# </style><table id="T_1e113_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >reordered</th>    </tr>    <tr>        <th class="index_name level0" >user_id</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1e113_level0_row0" class="row_heading level0 row0" >2</th>
#                         <td id="T_1e113_row0_col0" class="data row0 col0" >3.8%</td>
#             </tr>
#             <tr>
#                         <th id="T_1e113_level0_row1" class="row_heading level0 row1" >4</th>
#                         <td id="T_1e113_row1_col0" class="data row1 col0" >0.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_1e113_level0_row2" class="row_heading level0 row2" >5</th>
#                         <td id="T_1e113_row2_col0" class="data row2 col0" >66.7%</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# The strategy to find the solution is to:
# Merge instacart orders with order data
# Get reorder ratio using user_id and reorder
# Display the results.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 3</b>
#
# ✔️ This looks good!
#
#
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 2</b>
#
# You need to group by `user_id` without grouping by `order`. Then you will find the mean value of the orders (0s) and reorders(1s) or the client, which is the reorder ratio.
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 1</b>
#
# Please try to use the approach I showed above to get the reorders for customers.

# %% [markdown]
# ### [C5] What are the top 20 items that people put in their carts first?

# %%
#Merge DFs to get name and ID
first_product_merge=order_products.merge(products,on='product_id')

first_product_merge=first_product_merge[order_products['add_to_cart_order']==1]

#count each instance
first_order_counts=first_product_merge.groupby(['product_id', 'product_name'])['order_id'].count().reset_index(name='count')

# Sort and get the top 20 products
top_20_products = first_order_counts.sort_values(by='count', ascending=False).head(20)

print(top_20_products)
# Out:
#        product_id              product_name  count
# 13983       24852                    Banana   6642
# 7361        13176    Bag of Organic Bananas   5355
# 11890       21137      Organic Strawberries   3634
# 12327       21903      Organic Baby Spinach   3297
# 26554       47209      Organic Hass Avocado   2996
# 26864       47766           Organic Avocado   2459
# 26786       47626               Large Lemon   2125
# 14718       26209                     Limes   1991
# 9401        16797              Strawberries   1984
# 15610       27845        Organic Whole Milk   1973
# 15682       27966       Organic Raspberries   1850
# 12911       22935      Organic Yellow Onion   1540
# 25318       45007          Organic Zucchini   1478
# 14043       24964            Organic Garlic   1450
# 22094       39275       Organic Blueberries   1338
# 27954       49683            Cucumber Kirby   1319
# 15811       28204        Organic Fuji Apple   1247
# ...

# %% [markdown]
# To find the top 20 items that people first put in their cart the first step was to filter order_products
# to only include the first product added to the cart, add_to_cart_order=1.
# Next the products df was merged to include the product name.
# Finally, the number of times each unique product appeared was counted to find the top 20.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 2</b>
#
# ✔️
#
#
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 1</b>
#
# Please try to correct in line with my instructions above.`

# %% [markdown]
# Conclusion:
#
# After a thorough review of instacart's orders the patterns of shoppers emerged. The most common day and hour of orders was found. As well as the most common product ordered, reordered, and to what percent.
# Key take-aways from the data include:
#
# The most common time when orders are placed is at 10, with 40578, followed closely by 11, with 40032.
# Orders are most commonly placed on Sunday and decline sharply after Monday.
# Users regularly place orders after a 7 day and 30 day wait.
# The average customer places three orders.
# Customers normally order ten products.
# The top ten most ordered products and reordered products are almost exclusively produce with some dairy.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 3</b>
#
# ✔️
#
#
#
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Reviewer's comment, v. 2</b>
#
# Please make sure for the future projects the conclusions are specifiс and summarise the results of analysis. Basically, you could desciribe everything you found out in the second part.
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 1</b>
#
# Could you please add an overall conclusion summarizing the main findings from your analysis?
#
# Including a conclusion is a critical part of your project, as it effectively ties together all of the key insights and demonstrates the business impact of your work. It gives readers a clear and concise understanding of the data’s story, how the findings can be applied, and what decisions or actions might follow.
